# %%
import sig_proc as s

from numpy import *
import matplotlib.pyplot as plt

# %%
SIGNAL_FILE = 'wave.ascii'
TIME_PER_PIXEL=0.1
SAMPLE_RATE = 500

# %%
signal = loadtxt(open(SIGNAL_FILE))

# %%
time_axis=s.get_time_axis(signal,SAMPLE_RATE)
plt.scatter(time_axis,signal)

# %%
NOISE_AMP = 50 #20 percent of max signal amplitude
signal = s.add_noise(signal,NOISE_AMP)

# %%
restored_pic = s.process_signal(signal,SAMPLE_RATE,TIME_PER_PIXEL)
# Out:
# DIM= 50 50

# %%
plt.imshow(restored_pic, 'gray')
