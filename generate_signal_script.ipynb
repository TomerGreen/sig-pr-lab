# %%
import sig_proc as s
from numpy import *
import matplotlib.pyplot as plt
 
import imageio
from PIL import Image

# %%
FREQ = 50
TIME_PER_PIXEL=0.1
SAMPLE_RATE = 500

# %%
ORIGINAL_FILE = 'pic.png'
PIC_FILE='c.png' #cropped file name

# %%
#get image and crop it
imageObject = Image.open(ORIGINAL_FILE).convert('L')
cropped     = imageObject.crop((250,150,300,200))
cropped.save(PIC_FILE)
plt.imshow(imageObject,'gray')

# %%
pic = imageio.imread(PIC_FILE,pilmode='L')
plt.imshow(pic,'gray')

# %%
pic_arr = s.pic_to_arr(pic)

# %%
plt.imshow(pic_arr,'gray')

# %%
signal = s.modulate_arr(pic_arr,FREQ,TIME_PER_PIXEL,SAMPLE_RATE)

# %%
time_axis=arange(0,size(signal)/SAMPLE_RATE,1/SAMPLE_RATE)
plt.scatter(time_axis,signal)

# %%
savetxt('wave.ascii',signal,delimiter=', ')
